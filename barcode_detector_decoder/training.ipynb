# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c397b9f-2894-47b7-881a-2652b67a2936" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c397b9f-2894-47b7-881a-2652b67a2936">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os
from ultralytics import YOLO

# ✅ Step 1: Extract the dataset
zip_path = "/content/BC_nuevo_externo.v5-without-augmentation.yolov8.zip"
extract_path = "/content/BC_nuevo_externo.v5-without-augmentation.yolov8"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted successfully!")

# ✅ Step 2: Define the dataset path
data_yaml_path ="/content/BC_nuevo_externo.v5-without-augmentation.yolov8/BC_nuevo_externo.v5-without-augmentation.yolov8/data.yaml"

# ✅ Step 3: Load YOLOv8 model
model = YOLO("yolov8n.pt")  # Using YOLOv8 nano model (change to yolov8s.pt, yolov8m.pt if needed)

# ✅ Step 4: Train the model
model.train(data=data_yaml_path, epochs=50, imgsz=640, batch=16)

print("🚀 Training Complete!")
# Out:
# ✅ Dataset extracted successfully!
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# ✅ Step 5: Save the trained model
best_model_path = "/content/runs/detect/train3/weights/best.pt"

# ✅ Step 6: Download the trained model
from google.colab import files
files.download(best_model_path)

print("✅ Model saved and ready to download!")
# Out:
# ✅ Model saved and ready to download!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
